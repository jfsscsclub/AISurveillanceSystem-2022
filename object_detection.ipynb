# %%
import numpy as np
# import tensorflow as tf
import tensorflow_hub as hub
import cv2

# %% [markdown]
# # Load the model

# %%
print('loading model...')
hub_model = hub.load("https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2")
print('model loaded!')
# Out:
# loading model...
# model loaded!

# %% [markdown]
# # Load image

# %%
img = [cv2.imread('beach.jpg')] # In an array due to input shape of model
image_width = img[0].shape[1]
image_height = img[0].shape[0]

# %%
print(image_width, image_height)
# Out:
# 1352 900

# %% [markdown]
# # Run inference

# %%
results = hub_model(img)

# %%
results["detection_boxes"]
# Out:
# <tf.Tensor: shape=(1, 100, 4), dtype=float32, numpy=
# array([[[0.55710393, 0.39231232, 0.59130245, 0.4103807 ],
#         [0.57152694, 0.03911226, 0.62067527, 0.05934257],
#         [0.08669013, 0.4410252 , 0.16529241, 0.50445706],
#         [0.56772935, 0.0617691 , 0.6196408 , 0.08572271],
#         [0.75473714, 0.16105339, 0.9397696 , 0.20695218],
#         [0.2679266 , 0.20715071, 0.30811587, 0.22549193],
#         [0.43214557, 0.793667  , 0.47185817, 0.82428557],
#         [0.3756977 , 0.34603983, 0.404128  , 0.36724627],
#         [0.26665562, 0.20959884, 0.3094563 , 0.23259771],
#         [0.687977  , 0.09010244, 0.8361092 , 0.13337983],
#         [0.6951026 , 0.08188684, 0.8169466 , 0.12225036],
#         [0.59892976, 0.13161354, 0.62225986, 0.14287652],
#         [0.44089878, 0.7859637 , 0.47105753, 0.80761284],
#         [0.5555733 , 0.37513718, 0.5763634 , 0.3851138 ],
#         [0.62226385, 0.60501015, 0.6364139 , 0.62182367],
#         [0.4156721 , 0.23034585, 0.4311892 , 0.24573743],
#         [0.571052  , 0.38682076, 0.59713775, 0.40837368],
#         [0.5717516 , 0.04012839, 0.5943179 , 0.05261235],
#         [0.38756293, 0.42782953, 0.40443116, 0.4409419 ],
#         [0.5681388 , 0.6539179 , 0.58128923, 0.6683363 ],
#         [0.57284945, 0.07526708, 0.59644276, 0.08963178],
#         [0.5482388 , 0.25938424, 0.5614099 , 0.26867077],
#         [0.5269575 , 0.24992178, 0.5356338 , 0.2575302 ],
#         [0.43677953, 0.22332737, 0.46701464, 0.24471536],
#         [0.6861171 , 0.08683889, 0.7601493 , 0.1190333 ],
#         [0.3869441 , 0.43306893, 0.4017832 , 0.44895446],
#         [0.5070113 , 0.2953761 , 0.5208405 , 0.31029317],
#         [0.3743632 , 0.34811467, 0.38720325, 0.36350077],
#         [0.752001  , 0.15208204, 0.9777444 , 0.21586137],
#         [0.85978425, 0.09217659, 0.8865503 , 0.11540924],
#         [0.33067185, 0.01319519, 0.71475536, 0.96335495],
#         [0.80411494, 0.0850945 , 0.8424325 , 0.11677903],
#         [0.3869441 , 0.43306893, 0.4017832 , 0.44895446],
#         [0.55710393, 0.39231232, 0.59130245, 0.4103807 ],
#         [0.34577286, 0.00524575, 0.68570375, 0.9670604 ],
#         [0.5070113 , 0.2953761 , 0.5208405 , 0.31029317],
#         [0.5578873 , 0.30208912, 0.5693306 , 0.31016222],
#         [0.75473714, 0.16105339, 0.9397696 , 0.20695218],
#         [0.46506965, 0.03582469, 0.62001073, 0.87773395],
#         [0.6916791 , 0.0954089 , 0.7676705 , 0.12948816],
#         [0.41692597, 0.55885917, 0.43060148, 0.5700328 ],
#         [0.44089878, 0.7859637 , 0.47105753, 0.80761284],
#         [0.5678554 , 0.61826   , 0.5787417 , 0.6339246 ],
#         [0.35487643, 0.09969476, 0.55742335, 0.8640748 ],
#         [0.08669013, 0.4410252 , 0.16529241, 0.50445706],
#         [0.5269575 , 0.24992178, 0.5356338 , 0.2575302 ],
#         [0.46268123, 0.1847714 , 0.48142838, 0.20476253],
#         [0.5482388 , 0.25938424, 0.5614099 , 0.26867077],
#         [0.26665562, 0.20959884, 0.3094563 , 0.23259771],
#         [0.6852456 , 0.08203588, 0.93855184, 0.17407356],
#         [0.75006104, 0.6592713 , 0.8845887 , 0.95603937],
#         [0.46268123, 0.1847714 , 0.48142838, 0.20476253],
#         [0.38756293, 0.42782953, 0.40443116, 0.4409419 ],
#         [0.45455167, 0.28257525, 0.47746012, 0.3075189 ],
#         [0.57316214, 0.5646511 , 0.587758  , 0.58515745],
#         [0.20370957, 0.02366093, 0.8355671 , 0.95276856],
#         [0.8840404 , 0.17426734, 0.9506878 , 0.2028972 ],
#         [0.80411494, 0.0850945 , 0.8424325 , 0.11677903],
#         [0.75473714, 0.16105339, 0.9397696 , 0.20695218],
#         [0.01181987, 0.02803454, 0.6858927 , 0.78806305],
#         [0.5434633 , 0.04688916, 0.9721989 , 0.96036685],
#         [0.21933708, 0.        , 0.88372004, 0.9526484 ],
#         [0.55710393, 0.39231232, 0.59130245, 0.4103807 ],
#         [0.55710393, 0.39231232, 0.59130245, 0.4103807 ],
#         [0.26268932, 0.21056478, 0.28157517, 0.2242269 ],
#         [0.26268932, 0.21056478, 0.28157517, 0.2242269 ],
#         [0.8840404 , 0.17426734, 0.9506878 , 0.2028972 ],
#         [0.2679266 , 0.20715071, 0.30811587, 0.22549193],
#         [0.43214557, 0.793667  , 0.47185817, 0.82428557],
#         [0.2679266 , 0.20715071, 0.30811587, 0.22549193],
#         [0.46268123, 0.1847714 , 0.48142838, 0.20476253],
#         [0.9454153 , 0.157272  , 0.99790615, 0.20747264],
#         [0.3756977 , 0.34603983, 0.404128  , 0.36724627],
#         [0.79543555, 0.10435659, 0.8402518 , 0.13613008],
#         [0.62226385, 0.60501015, 0.6364139 , 0.62182367],
#         [0.49008444, 0.18674707, 0.5061475 , 0.20013896],
#         [0.4891641 , 0.14164181, 0.50559735, 0.15767504],
#         [0.6951026 , 0.08188684, 0.8169466 , 0.12225036],
#         [0.43677953, 0.22332737, 0.46701464, 0.24471536],
#         [0.51968724, 0.33998817, 0.52944285, 0.3509515 ],
#         [0.6951026 , 0.08188684, 0.8169466 , 0.12225036],
#         [0.8840404 , 0.17426734, 0.9506878 , 0.2028972 ],
#         [0.6951026 , 0.08188684, 0.8169466 , 0.12225036],
#         [0.43677953, 0.22332737, 0.46701464, 0.24471536],
#         [0.59892976, 0.13161354, 0.62225986, 0.14287652],
#         [0.75473714, 0.16105339, 0.9397696 , 0.20695218],
#         [0.08669013, 0.4410252 , 0.16529241, 0.50445706],
#         [0.43589517, 0.5650379 , 0.45162526, 0.5767837 ],
#         [0.80411494, 0.0850945 , 0.8424325 , 0.11677903],
#         [0.6951026 , 0.08188684, 0.8169466 , 0.12225036],
#         [0.85859805, 0.10612611, 0.8946822 , 0.15042248],
#         [0.41692597, 0.55885917, 0.43060148, 0.5700328 ],
#         [0.49490348, 0.88019073, 0.5051409 , 0.8903532 ],
#         [0.56772935, 0.0617691 , 0.6196408 , 0.08572271],
#         [0.10910659, 0.04176235, 0.51988906, 0.9095966 ],
#         [0.836434  , 0.8941911 , 0.8716513 , 0.9664728 ],
#         [0.57316214, 0.5646511 , 0.587758  , 0.58515745],
#         [0.41732785, 0.21766445, 0.4259685 , 0.22550061],
#         [0.46187037, 0.01667576, 0.4869715 , 0.02863379],
#         [0.44683695, 0.        , 0.63648653, 0.6282377 ]]], dtype=float32)>

# %% [markdown]
# # Prepare results into readable format

# %%
category_index = {
    1: {'id': 1, 'name': 'person'},
    2: {'id': 2, 'name': 'bicycle'},
    3: {'id': 3, 'name': 'car'},
    4: {'id': 4, 'name': 'motorcycle'}
}

# %%
classes = (results['detection_classes'][0].numpy() + 0).astype(int)

# get label and coordinates of detected objects
objects = []
for index, score in enumerate(results['detection_scores'][0]):
    # print(index)
    label = "?"
    if classes[index] in category_index.keys():
        label = category_index[classes[index]]['name']
    else:
        # Skip those without labels (we don't need them)
        continue

    ymin, xmin, ymax, xmax = results['detection_boxes'][0][index]
    # print(label)
    objects.append((label, int(xmin * image_width), int(ymin * image_height), int(xmax * image_width), int(ymax * image_height)))

# %%
objects
# Out:
# [('person', 530, 501, 554, 532),
#  ('person', 52, 514, 80, 558),
#  ('person', 83, 510, 115, 557),
#  ('person', 217, 679, 279, 845),
#  ('person', 1073, 388, 1114, 424),
#  ('person', 121, 619, 180, 752),
#  ('person', 110, 625, 165, 735),
#  ('person', 177, 539, 193, 560),
#  ('person', 1062, 396, 1091, 423),
#  ('person', 507, 500, 520, 518),
#  ('person', 522, 513, 552, 537),
#  ('person', 54, 514, 71, 534),
#  ('person', 101, 515, 121, 536),
#  ('person', 350, 493, 363, 505),
#  ('person', 337, 474, 348, 482),
#  ('person', 117, 617, 160, 684),
#  ('person', 399, 456, 419, 468),
#  ('person', 205, 676, 291, 879),
#  ('person', 7, 311, 1307, 617),
#  ('person', 408, 502, 419, 512),
#  ('person', 48, 418, 1186, 558),
#  ('person', 128, 622, 175, 690),
#  ('person', 110, 616, 235, 844),
#  ('person', 115, 723, 157, 758),
#  ('person', 63, 489, 1298, 874),
#  ('person', 0, 197, 1287, 795),
#  ('person', 249, 416, 276, 433),
#  ('person', 141, 715, 184, 756),
#  ('person', 817, 560, 840, 572),
#  ('person', 252, 441, 270, 455),
#  ('person', 191, 440, 213, 455),
#  ('person', 459, 467, 474, 476),
#  ('person', 235, 795, 274, 855),
#  ('person', 301, 393, 330, 420),
#  ('person', 763, 392, 779, 406),
#  ('person', 1190, 445, 1203, 454),
#  ('person', 22, 415, 38, 438),
#  ('person', 0, 402, 849, 572)]

# %%
img_annotated = np.copy(img[0])

# %% [markdown]
# # Start drawing onto image

# %%
for obj in objects:
    print(obj[1], obj[2], obj[3], obj[4])
    img_annotated = cv2.rectangle(img_annotated, (obj[1], obj[2]), (obj[3], obj[4]), (0, 255, 0), 3)
# Out:
# 530 501 554 532
# 52 514 80 558
# 83 510 115 557
# 217 679 279 845
# 1073 388 1114 424
# 121 619 180 752
# 110 625 165 735
# 177 539 193 560
# 1062 396 1091 423
# 507 500 520 518
# 522 513 552 537
# 54 514 71 534
# 101 515 121 536
# 350 493 363 505
# 337 474 348 482
# 117 617 160 684
# 399 456 419 468
# 205 676 291 879
# 7 311 1307 617
# 408 502 419 512
# 48 418 1186 558
# 128 622 175 690
# 110 616 235 844
# 115 723 157 758
# 63 489 1298 874
# 0 197 1287 795
# 249 416 276 433
# 141 715 184 756
# 817 560 840 572
# 252 441 270 455
# 191 440 213 455
# 459 467 474 476
# 235 795 274 855
# 301 393 330 420
# 763 392 779 406
# 1190 445 1203 454
# 22 415 38 438
# 0 402 849 572

# %%
cv2.imwrite("beach_annotated.png", img_annotated)
# Out:
# True
